# %%
import json
import os
import utils
import torch
import torch.nn.functional as F

model_dir = "experiments/"
json_path = os.path.join(model_dir, 'params.json')
params = utils.Params(json_path)
params.device = torch.device(params.device)

# %%
from model.data_loader import DataLoader

data_dir = "data/full_version/"
data_loader = DataLoader(data_dir, params)
params.vocab_size = len(data_loader.BABYNAME.vocab)
# Out:
# vocab built

# %%
import pandas as pd

_train = pd.read_csv(os.path.join(data_dir, "train/train_dataset.csv"))
_val = pd.read_csv(os.path.join(data_dir, "val/val_dataset.csv"))
total_df = pd.concat([_train, _val], 0)

# %%
import model.charRNN as net
model = net.Net(params).to(params.device)

# %%
weight_path = os.path.join(model_dir, "best.pth.tar")
checkpoint = utils.load_checkpoint(weight_path, model)

# %%
from collections import OrderedDict, defaultdict

# %%
data_loader.SEX.process(['boy'])
# Out:
# tensor([[ 0,  1]])

# %%
data_loader.SEX.process(['girl'])
# Out:
# tensor([[ 1,  0]])

# %%
def sample(net, prime, category):
    
    category_tensor = data_loader.SEX.process([category]).float()
    
    prime = prime.lower()
    prime_tensor = data_loader.BABYNAME.process([prime])[:, :-1]
    bsz, prime_tensor_length = prime_tensor.size()
    
    net.eval()
    hidden = net.init_hidden(1)
    
    for step in range(prime_tensor_length):
        with torch.no_grad():
            outputs, hidden = net(category_tensor, prime_tensor[:, step], hidden)
        probabilities = F.softmax(outputs, 1)
    
    return torch.log(probabilities.squeeze()), hidden

# %%
def clean_beam_basket(basket, beam_width):
    _tmp_basket = basket.copy()
    to_remove = sorted(_tmp_basket.items(), key=lambda x: x[1], reverse=True)[beam_width:]
    for item in to_remove:
        _tmp_basket.pop(item[0])
        
    return _tmp_basket

# %%
import numpy as np

# %%
def evaluate_creativity(name_list, dataset):
    for a_name in name_list:
        if dataset.babyname.str.contains(a_name).sum() > 0:
            verdict = "is already in the dataset"
        else:
            verdict = "is a new name!"
        print("name: {} ".format(a_name) + verdict)

# %%
def beam_search(net, beam_width, alpha, prime="A", category="boy"):
    print("Sampling a {} name beginning with {}..".format(category, prime))
        
    beam_basket = OrderedDict()
    beam_basket[prime] = 0.0
    
    
    counter = 0
    while True:
        counter += 1
        
        # 바스켓을 청소한다.
        beam_basket = clean_beam_basket(beam_basket, beam_width)
        
        # 만약 바스켓에 모든 아이템이 <eos>가 있으면 루프를 멈춘다.
        eos_cnt = 0
        for k in beam_basket.keys():
            if "<eos>" in k:
                eos_cnt += 1
        if eos_cnt == beam_width:
            print("all items have <eos>")
            break
            
        # 모든 key를 돌면서
        ## <eos>가 없는 경우 inference를 한다.
        new_entries = {}
        to_remove = []
        for k in beam_basket.keys():
            if "<eos>" not in k:
                probabilities, hidden = sample(net, prime=k, category=category)
                for ix, prob in enumerate(probabilities):
                    new_k = k + data_loader.BABYNAME.vocab.itos[ix]
                    added_probability = beam_basket[k] + prob.item()
                    len_k = len(k.replace("<eos>", ""))
                    normalized_probability = (1 / (len(k) ** alpha)) * added_probability 
                    new_entries[new_k] = normalized_probability
                to_remove.append(k)
        # 그리고 기존 key를 beam_basket에서 지운다.
        for k in to_remove:
            beam_basket.pop(k)
        
        for k, v in new_entries.items():
            beam_basket[k] = v
            
    final_list = []
    for k, v in beam_basket.items():
        refined_k = k.replace("<eos>", "").capitalize()
        final_list.append(refined_k)
        final_prob = np.exp(v)
                
    return final_list
            
        
        
    
# final_list = beam_search(model, prime='A', category='boy')

# %%
def generate_names(net, prime, category, beam_width, dataset, alpha=0.7):
    final_list = beam_search(net, prime=prime, category=category, beam_width=beam_width, alpha=alpha)
    
    evaluate_creativity(final_list, dataset)
    
generate_names(model, prime="A", category="girl", beam_width=3, dataset=total_df)
generate_names(model, prime="A", category="boy", beam_width=3, dataset=total_df)
# Out:
# Sampling a girl name beginning with A..
# all items have <eos>
# name: Annessa is a new name!
# name: Allissa is already in the dataset
# name: Allissandre is a new name!
# Sampling a boy name beginning with A..
# all items have <eos>
# name: Andrio is a new name!
# name: Arnell is already in the dataset
# name: Andrick is already in the dataset

# %%
import string

# %%
for sex in ['boy', 'girl']:
    for char in string.ascii_uppercase:
        generate_names(model, prime=char, category=sex, beam_width=3, dataset=total_df)
        print(" ")
# Out:
# Sampling a boy name beginning with A..
# all items have <eos>
# name: Andrio is a new name!
# name: Arnell is already in the dataset
# name: Andrick is already in the dataset
#
# Sampling a boy name beginning with B..
# all items have <eos>
# name: Branly is already in the dataset
# name: Branley is already in the dataset
# name: Branleigh is a new name!
#
# Sampling a boy name beginning with C..
# all items have <eos>
# name: Carles is a new name!
# name: Carlis is already in the dataset
# name: Carlison is a new name!
#
# Sampling a boy name beginning with D..
# all items have <eos>
# name: Derick is already in the dataset
# name: Derrik is already in the dataset
# name: Derrick is already in the dataset
#
# Sampling a boy name beginning with E..
# all items have <eos>
# name: Ellfred is already in the dataset
# name: Everley is already in the dataset
# name: Ellfredge is a new name!
#
# Sampling a boy name beginning with F..
# all items have <eos>
# name: Farren is a new name!
# name: Farris is already in the dataset
# name: Fabiano is already in the dataset
#
# Sampling a boy name beginning with G..
# all items have <eos>
# name: Garrel is a new name!
# name: Garrell is a new name!
# name: Gerrick is already in the dataset
#
# Sampling a boy name beginning with H..
# all items have <eos>
# name: Haller is a new name!
# name: Harlen is already in the dataset
# name: Harrison is already in the dataset
#
# Sampling a boy name beginning with I..
# all items have <eos>
# name: Isander is already in the dataset
# name: Isandro is already in the dataset
# name: Isandrio is a new name!
#
# Sampling a boy name beginning with J..
# all items have <eos>
# name: Jerrik is already in the dataset
# name: Jarrell is already in the dataset
# name: Jerrick is already in the dataset
#
# Sampling a boy name beginning with K..
# all items have <eos>
# name: Kendrik is already in the dataset
# name: Kirillo is already in the dataset
# name: Kendrick is already in the dataset
#
# Sampling a boy name beginning with L..
# all items have <eos>
# name: Lander is already in the dataset
# name: Lorrence is already in the dataset
# name: Lorrencio is a new name!
#
# Sampling a boy name beginning with M..
# all items have <eos>
# name: Michal is already in the dataset
# name: Michall is already in the dataset
# name: Michell is already in the dataset
#
# Sampling a boy name beginning with N..
# all items have <eos>
# name: Nathan is already in the dataset
# name: Nikolo is already in the dataset
# name: Nathani is already in the dataset
#
# Sampling a boy name beginning with O..
# all items have <eos>
# name: Oliver is already in the dataset
# name: Olivero is already in the dataset
# name: Oliverio is already in the dataset
#
# Sampling a boy name beginning with P..
# all items have <eos>
# name: Percio is a new name!
# name: Priscolf is a new name!
# name: Princenzio is a new name!
#
# Sampling a boy name beginning with Q..
# all items have <eos>
# name: Quentin is already in the dataset
# name: Quillio is a new name!
# name: Quilleigh is a new name!
#
# Sampling a boy name beginning with R..
# all items have <eos>
# name: Randley is a new name!
# name: Rodrick is already in the dataset
# name: Roderick is already in the dataset
#
# Sampling a boy name beginning with S..
# all items have <eos>
# name: Stefan is already in the dataset
# name: Stefar is a new name!
# name: Stefford is a new name!
#
# Sampling a boy name beginning with T..
# all items have <eos>
# name: Theodor is already in the dataset
# name: Thorsten is already in the dataset
# name: Thorston is a new name!
#
# Sampling a boy name beginning with U..
# all items have <eos>
# name: Uriel is already in the dataset
# name: Uriano is a new name!
# name: Uriell is already in the dataset
#
# Sampling a boy name beginning with V..
# all items have <eos>
# name: Valler is already in the dataset
# name: Vicker is a new name!
# name: Valerio is already in the dataset
#
# Sampling a boy name beginning with W..
# all items have <eos>
# name: Willie is already in the dataset
# name: Willis is already in the dataset
# name: Willier is a new name!
#
# Sampling a boy name beginning with X..
# all items have <eos>
# name: Xandro is already in the dataset
# name: Xandros is already in the dataset
# name: Xindrick is a new name!
#
# Sampling a boy name beginning with Y..
# all items have <eos>
# name: Yashim is a new name!
# name: Yerrik is a new name!
# name: Yerrick is a new name!
#
# Sampling a boy name beginning with Z..
# all items have <eos>
# name: Zandrio is a new name!
# name: Zacharia is already in the dataset
# name: Zachiria is a new name!
#
# Sampling a girl name beginning with A..
# all items have <eos>
# name: Annessa is a new name!
# name: Allissa is already in the dataset
# name: Allissandre is a new name!
#
# Sampling a girl name beginning with B..
# all items have <eos>
# name: Brenna is already in the dataset
# name: Brittanni is already in the dataset
# name: Brittannie is already in the dataset
#
# Sampling a girl name beginning with C..
# all items have <eos>
# name: Chantal is already in the dataset
# name: Cherissa is a new name!
# name: Cherisse is already in the dataset
#
# Sampling a girl name beginning with D..
# all items have <eos>
# name: Delisa is already in the dataset
# name: Dannelle is already in the dataset
# name: Dannielle is already in the dataset
#
# Sampling a girl name beginning with E..
# all items have <eos>
# name: Ellissa is already in the dataset
# name: Ellisse is a new name!
# name: Elisabeth is already in the dataset
#
# Sampling a girl name beginning with F..
# all items have <eos>
# name: Felicia is already in the dataset
# name: Franciska is already in the dataset
# name: Frederice is a new name!
#
# Sampling a girl name beginning with G..
# all items have <eos>
# name: Gennie is already in the dataset
# name: Gennis is already in the dataset
# name: Gennisha is a new name!
#
# Sampling a girl name beginning with H..
# all items have <eos>
# name: Hallee is already in the dataset
# name: Hilderika is a new name!
# name: Hilderike is a new name!
#
# Sampling a girl name beginning with I..
# all items have <eos>
# name: Irina is already in the dataset
# name: Isabel is already in the dataset
# name: Isabelle is already in the dataset
#
# Sampling a girl name beginning with J..
# all items have <eos>
# name: Janeesa is already in the dataset
# name: Jennell is already in the dataset
# name: Jennisha is already in the dataset
#
# Sampling a girl name beginning with K..
# all items have <eos>
# name: Katrina is already in the dataset
# name: Kathlinn is already in the dataset
# name: Kathlinne is already in the dataset
#
# Sampling a girl name beginning with L..
# all items have <eos>
# name: Linda is already in the dataset
# name: Lindie is already in the dataset
# name: Laticia is already in the dataset
#
# Sampling a girl name beginning with M..
# all items have <eos>
# name: Marcie is already in the dataset
# name: Melissa is already in the dataset
# name: Melisse is already in the dataset
#
# Sampling a girl name beginning with N..
# all items have <eos>
# name: Natalia is already in the dataset
# name: Nicoline is already in the dataset
# name: Nicolette is already in the dataset
#
# Sampling a girl name beginning with O..
# all items have <eos>
# name: Oralie is already in the dataset
# name: Oriana is already in the dataset
# name: Orianne is already in the dataset
#
# Sampling a girl name beginning with P..
# all items have <eos>
# name: Perlina is a new name!
# name: Perline is already in the dataset
# name: Priscilla is already in the dataset
#
# Sampling a girl name beginning with Q..
# all items have <eos>
# name: Quillie is a new name!
# name: Quentine is a new name!
# name: Quillianne is a new name!
#
# Sampling a girl name beginning with R..
# all items have <eos>
# name: Rosalynn is already in the dataset
# name: Roselynn is already in the dataset
# name: Rozelynn is a new name!
#
# Sampling a girl name beginning with S..
# all items have <eos>
# name: Sherrie is already in the dataset
# name: Shantell is already in the dataset
# name: Shantelle is already in the dataset
#
# Sampling a girl name beginning with T..
# all items have <eos>
# name: Terree is already in the dataset
# name: Terrie is already in the dataset
# name: Terisha is a new name!
#
# Sampling a girl name beginning with U..
# all items have <eos>
# name: Uriana is a new name!
# name: Urianne is a new name!
# name: Urielle is a new name!
#
# Sampling a girl name beginning with V..
# all items have <eos>
# name: Vickee is already in the dataset
# name: Vickie is already in the dataset
# name: Vernice is already in the dataset
#
# Sampling a girl name beginning with W..
# all items have <eos>
# name: Winora is a new name!
# name: Willee is already in the dataset
# name: Willie is already in the dataset
#
# Sampling a girl name beginning with X..
# all items have <eos>
# name: Xandria is already in the dataset
# name: Xandrina is a new name!
# name: Xandrine is a new name!
#
# Sampling a girl name beginning with Y..
# all items have <eos>
# name: Yannee is a new name!
# name: Yolanda is already in the dataset
# name: Yolande is already in the dataset
#
# Sampling a girl name beginning with Z..
# all items have <eos>
# name: Zandra is already in the dataset
# name: Zorina is already in the dataset
# name: Zandria is a new name!

# %%
for sex in ['boy', 'girl']:
    for char in string.ascii_uppercase:
        generate_names(model, prime=char, category=sex, beam_width=3, dataset=total_df, alpha=1.0)
        print(" ")
# Out:
# Sampling a boy name beginning with A..
# all items have <eos>
# name: Andrio is a new name!
# name: Arnell is already in the dataset
# name: Andrick is already in the dataset
#
# Sampling a boy name beginning with B..
# all items have <eos>
# name: Branly is already in the dataset
# name: Bartham is a new name!
# name: Branley is already in the dataset
#
# Sampling a boy name beginning with C..
# all items have <eos>
# name: Carles is a new name!
# name: Carlis is already in the dataset
# name: Carlison is a new name!
#
# Sampling a boy name beginning with D..
# all items have <eos>
# name: Derick is already in the dataset
# name: Derrik is already in the dataset
# name: Derrick is already in the dataset
#
# Sampling a boy name beginning with E..
# all items have <eos>
# name: Ellfred is already in the dataset
# name: Everley is already in the dataset
# name: Ellfredge is a new name!
#
# Sampling a boy name beginning with F..
# all items have <eos>
# name: Fabio is already in the dataset
# name: Fabion is already in the dataset
# name: Fabiano is already in the dataset
#
# Sampling a boy name beginning with G..
# all items have <eos>
# name: Gerrick is already in the dataset
# name: Garrison is already in the dataset
# name: Grantley is already in the dataset
#
# Sampling a boy name beginning with H..
# all items have <eos>
# name: Haller is a new name!
# name: Harlen is already in the dataset
# name: Harrison is already in the dataset
#
# Sampling a boy name beginning with I..
# all items have <eos>
# name: Isander is already in the dataset
# name: Isandro is already in the dataset
# name: Isandrio is a new name!
#
# Sampling a boy name beginning with J..
# all items have <eos>
# name: Jarrell is already in the dataset
# name: Jarrick is a new name!
# name: Jerrick is already in the dataset
#
# Sampling a boy name beginning with K..
# all items have <eos>
# name: Kendrik is already in the dataset
# name: Kirillo is already in the dataset
# name: Kendrick is already in the dataset
#
# Sampling a boy name beginning with L..
# all items have <eos>
# name: Lander is already in the dataset
# name: Lorrence is already in the dataset
# name: Lorrencio is a new name!
#
# Sampling a boy name beginning with M..
# all items have <eos>
# name: Michal is already in the dataset
# name: Michall is already in the dataset
# name: Michell is already in the dataset
#
# Sampling a boy name beginning with N..
# all items have <eos>
# name: Nikolo is already in the dataset
# name: Nathania is already in the dataset
# name: Nathaniah is a new name!
#
# Sampling a boy name beginning with O..
# all items have <eos>
# name: Oliver is already in the dataset
# name: Olivero is already in the dataset
# name: Oliverio is already in the dataset
#
# Sampling a boy name beginning with P..
# all items have <eos>
# name: Percio is a new name!
# name: Priscolf is a new name!
# name: Princenzio is a new name!
#
# Sampling a boy name beginning with Q..
# all items have <eos>
# name: Quentin is already in the dataset
# name: Quillio is a new name!
# name: Quilleigh is a new name!
#
# Sampling a boy name beginning with R..
# all items have <eos>
# name: Randley is a new name!
# name: Rodrick is already in the dataset
# name: Roderick is already in the dataset
#
# Sampling a boy name beginning with S..
# all items have <eos>
# name: Stefan is already in the dataset
# name: Stefar is a new name!
# name: Stefford is a new name!
#
# Sampling a boy name beginning with T..
# all items have <eos>
# name: Theodor is already in the dataset
# name: Thorsten is already in the dataset
# name: Thorston is a new name!
#
# Sampling a boy name beginning with U..
# all items have <eos>
# name: Ullis is a new name!
# name: Uriel is already in the dataset
# name: Uriell is already in the dataset
#
# Sampling a boy name beginning with V..
# all items have <eos>
# name: Valler is already in the dataset
# name: Vicker is a new name!
# name: Valerio is already in the dataset
#
# Sampling a boy name beginning with W..
# all items have <eos>
# name: Willie is already in the dataset
# name: Willis is already in the dataset
# name: Willier is a new name!
#
# Sampling a boy name beginning with X..
# all items have <eos>
# name: Xandro is already in the dataset
# name: Xindrik is a new name!
# name: Xindrick is a new name!
#
# Sampling a boy name beginning with Y..
# all items have <eos>
# name: Yashim is a new name!
# name: Yerrik is a new name!
# name: Yerrick is a new name!
#
# Sampling a boy name beginning with Z..
# all items have <eos>
# name: Zandrio is a new name!
# name: Zacharia is already in the dataset
# name: Zachiria is a new name!
#
# Sampling a girl name beginning with A..
# all items have <eos>
# name: Annessa is a new name!
# name: Allissa is already in the dataset
# name: Allissandre is a new name!
#
# Sampling a girl name beginning with B..
# all items have <eos>
# name: Brenna is already in the dataset
# name: Brittanni is already in the dataset
# name: Brittannie is already in the dataset
#
# Sampling a girl name beginning with C..
# all items have <eos>
# name: Chantal is already in the dataset
# name: Cherissa is a new name!
# name: Cherisse is already in the dataset
#
# Sampling a girl name beginning with D..
# all items have <eos>
# name: Delisa is already in the dataset
# name: Dannelle is already in the dataset
# name: Dannielle is already in the dataset
#
# Sampling a girl name beginning with E..
# all items have <eos>
# name: Ellissa is already in the dataset
# name: Ellisse is a new name!
# name: Elisabeth is already in the dataset
#
# Sampling a girl name beginning with F..
# all items have <eos>
# name: Felicia is already in the dataset
# name: Franciska is already in the dataset
# name: Frederice is a new name!
#
# Sampling a girl name beginning with G..
# all items have <eos>
# name: Greta is already in the dataset
# name: Gennie is already in the dataset
# name: Gennis is already in the dataset
#
# Sampling a girl name beginning with H..
# all items have <eos>
# name: Hallee is already in the dataset
# name: Hilderika is a new name!
# name: Hilderike is a new name!
#
# Sampling a girl name beginning with I..
# all items have <eos>
# name: Irina is already in the dataset
# name: Isabel is already in the dataset
# name: Isabelle is already in the dataset
#
# Sampling a girl name beginning with J..
# all items have <eos>
# name: Janeesa is already in the dataset
# name: Jennell is already in the dataset
# name: Jennisha is already in the dataset
#
# Sampling a girl name beginning with K..
# all items have <eos>
# name: Katrina is already in the dataset
# name: Kathlinn is already in the dataset
# name: Kathlinne is already in the dataset
#
# Sampling a girl name beginning with L..
# all items have <eos>
# name: Linda is already in the dataset
# name: Lindie is already in the dataset
# name: Laticia is already in the dataset
#
# Sampling a girl name beginning with M..
# all items have <eos>
# name: Marcie is already in the dataset
# name: Melissa is already in the dataset
# name: Melisse is already in the dataset
#
# Sampling a girl name beginning with N..
# all items have <eos>
# name: Natalia is already in the dataset
# name: Nicoline is already in the dataset
# name: Nicolette is already in the dataset
#
# Sampling a girl name beginning with O..
# all items have <eos>
# name: Oralie is already in the dataset
# name: Oriana is already in the dataset
# name: Orianne is already in the dataset
#
# Sampling a girl name beginning with P..
# all items have <eos>
# name: Perline is already in the dataset
# name: Princilla is a new name!
# name: Priscilla is already in the dataset
#
# Sampling a girl name beginning with Q..
# all items have <eos>
# name: Quentine is a new name!
# name: Quintina is already in the dataset
# name: Quillianne is a new name!
#
# Sampling a girl name beginning with R..
# all items have <eos>
# name: Rosalynn is already in the dataset
# name: Roselynn is already in the dataset
# name: Rozelynn is a new name!
#
# Sampling a girl name beginning with S..
# all items have <eos>
# name: Shantal is already in the dataset
# name: Sherrie is already in the dataset
# name: Shantell is already in the dataset
#
# Sampling a girl name beginning with T..
# all items have <eos>
# name: Terree is already in the dataset
# name: Terrie is already in the dataset
# name: Taniece is a new name!
#
# Sampling a girl name beginning with U..
# all items have <eos>
# name: Uriana is a new name!
# name: Urianne is a new name!
# name: Urielle is a new name!
#
# Sampling a girl name beginning with V..
# all items have <eos>
# name: Vickee is already in the dataset
# name: Vickie is already in the dataset
# name: Vernice is already in the dataset
#
# Sampling a girl name beginning with W..
# all items have <eos>
# name: Winora is a new name!
# name: Willee is already in the dataset
# name: Willie is already in the dataset
#
# Sampling a girl name beginning with X..
# all items have <eos>
# name: Xandria is already in the dataset
# name: Xandrina is a new name!
# name: Xandrine is a new name!
#
# Sampling a girl name beginning with Y..
# all items have <eos>
# name: Yannee is a new name!
# name: Yolanda is already in the dataset
# name: Yolande is already in the dataset
#
# Sampling a girl name beginning with Z..
# all items have <eos>
# name: Zandra is already in the dataset
# name: Zorina is already in the dataset
# name: Zandria is a new name!

# %%
for sex in ['boy', 'girl']:
    for char in string.ascii_uppercase:
        generate_names(model, prime=char, category=sex, beam_width=10, dataset=total_df, alpha=0.0)
        print(" ")
# Out:
# Sampling a boy name beginning with A..
# all items have <eos>
# name: Andro is already in the dataset
# name: Andrio is a new name!
# name: Alfino is a new name!
# name: Arnald is already in the dataset
# name: Arnell is already in the dataset
# name: Andrick is already in the dataset
# name: Allford is already in the dataset
# name: Aldrich is already in the dataset
# name: Aldrick is a new name!
# name: Alfonzio is a new name!
#
# Sampling a boy name beginning with B..
# all items have <eos>
# name: Branly is already in the dataset
# name: Branley is already in the dataset
# name: Branden is already in the dataset
# name: Brentin is already in the dataset
# name: Brently is already in the dataset
# name: Briston is a new name!
# name: Brandell is already in the dataset
# name: Brandley is a new name!
# name: Brentley is already in the dataset
# name: Branleigh is a new name!
#
# Sampling a boy name beginning with C..
# all items have <eos>
# name: Colly is already in the dataset
# name: Cristo is already in the dataset
# name: Colley is already in the dataset
# name: Collin is already in the dataset
# name: Cristof is already in the dataset
# name: Cristoff is a new name!
# name: Christof is already in the dataset
# name: Cristofor is already in the dataset
# name: Cristoforo is already in the dataset
# name: Cristoffer is a new name!
#
# Sampling a boy name beginning with D..
# all items have <eos>
# name: Damar is already in the dataset
# name: Darran is already in the dataset
# name: Darrel is already in the dataset
# name: Darrin is already in the dataset
# name: Derick is already in the dataset
# name: Derrik is already in the dataset
# name: Dandrio is a new name!
# name: Darrell is already in the dataset
# name: Darrick is already in the dataset
# name: Derrick is already in the dataset
#
# Sampling a boy name beginning with E..
# all items have <eos>
# name: Eldrig is already in the dataset
# name: Everil is already in the dataset
# name: Ephram is a new name!
# name: Ephrem is already in the dataset
# name: Ephrim is already in the dataset
# name: Eldrich is already in the dataset
# name: Everley is already in the dataset
# name: Eldridge is already in the dataset
# name: Evangelo is already in the dataset
# name: Eustachio is already in the dataset
#
# Sampling a boy name beginning with F..
# all items have <eos>
# name: Fabio is already in the dataset
# name: Farran is already in the dataset
# name: Farren is a new name!
# name: Farris is already in the dataset
# name: Fabion is already in the dataset
# name: Farnell is already in the dataset
# name: Farrell is already in the dataset
# name: Farrick is a new name!
# name: Fabiano is already in the dataset
# name: Felicio is already in the dataset
#
# Sampling a boy name beginning with G..
# all items have <eos>
# name: Garran is already in the dataset
# name: Garren is already in the dataset
# name: Garrel is a new name!
# name: George is already in the dataset
# name: Gillio is already in the dataset
# name: Garrald is a new name!
# name: Garrell is a new name!
# name: Garrick is already in the dataset
# name: Georgio is already in the dataset
# name: Giovanni is already in the dataset
#
# Sampling a boy name beginning with H..
# all items have <eos>
# name: Haller is a new name!
# name: Harlen is already in the dataset
# name: Herris is a new name!
# name: Hermon is already in the dataset
# name: Hiller is already in the dataset
# name: Herrick is already in the dataset
# name: Hermond is a new name!
# name: Hallburg is already in the dataset
# name: Hallford is already in the dataset
# name: Harrison is already in the dataset
#
# Sampling a boy name beginning with I..
# all items have <eos>
# name: Isan is already in the dataset
# name: Ivan is already in the dataset
# name: Indra is already in the dataset
# name: Issan is a new name!
# name: Ishar is a new name!
# name: Ingemar is already in the dataset
# name: Isander is already in the dataset
# name: Isandro is already in the dataset
# name: Issander is a new name!
# name: Issandro is a new name!
#
# Sampling a boy name beginning with J..
# all items have <eos>
# name: Jamar is already in the dataset
# name: Jarron is already in the dataset
# name: Jerrel is already in the dataset
# name: Jerric is already in the dataset
# name: Jerrik is already in the dataset
# name: Jarrell is already in the dataset
# name: Jarrick is a new name!
# name: Jerrald is already in the dataset
# name: Jerrell is already in the dataset
# name: Jerrick is already in the dataset
#
# Sampling a boy name beginning with K..
# all items have <eos>
# name: King is already in the dataset
# name: Kristo is already in the dataset
# name: Kendrik is already in the dataset
# name: Kirillo is already in the dataset
# name: Kristof is already in the dataset
# name: Kendrick is already in the dataset
# name: Kristoff is already in the dataset
# name: Kristofer is already in the dataset
# name: Kristofor is already in the dataset
# name: Kristoffer is already in the dataset
#
# Sampling a boy name beginning with L..
# all items have <eos>
# name: Lang is already in the dataset
# name: Lando is already in the dataset
# name: Lindo is already in the dataset
# name: Lander is already in the dataset
# name: Landon is already in the dataset
# name: Laurenz is already in the dataset
# name: Lindley is already in the dataset
# name: Lorrence is already in the dataset
# name: Laurenzio is a new name!
# name: Laurentino is a new name!
#
# Sampling a boy name beginning with M..
# all items have <eos>
# name: Marcio is already in the dataset
# name: Marvin is already in the dataset
# name: Michal is already in the dataset
# name: Michel is already in the dataset
# name: Martino is already in the dataset
# name: Marcell is already in the dataset
# name: Michall is already in the dataset
# name: Michell is already in the dataset
# name: Michiel is already in the dataset
# name: Marcelino is already in the dataset
#
# Sampling a boy name beginning with N..
# all items have <eos>
# name: Nicoll is already in the dataset
# name: Nicolo is already in the dataset
# name: Nikolo is already in the dataset
# name: Nicoles is a new name!
# name: Nicolio is a new name!
# name: Nicolis is already in the dataset
# name: Nicollo is a new name!
# name: Nicorio is a new name!
# name: Nicoleto is a new name!
# name: Nicolios is a new name!
#
# Sampling a boy name beginning with O..
# all items have <eos>
# name: Ondra is already in the dataset
# name: Ondro is a new name!
# name: Orrel is already in the dataset
# name: Orrin is already in the dataset
# name: Oliver is already in the dataset
# name: Olivio is already in the dataset
# name: Orrell is a new name!
# name: Ondrick is a new name!
# name: Octavio is already in the dataset
# name: Oliverio is already in the dataset
#
# Sampling a boy name beginning with P..
# all items have <eos>
# name: Patrio is a new name!
# name: Patric is already in the dataset
# name: Percio is a new name!
# name: Philip is already in the dataset
# name: Philos is a new name!
# name: Patrich is a new name!
# name: Philips is already in the dataset
# name: Phillis is already in the dataset
# name: Patricio is already in the dataset
# name: Priscolf is a new name!
#
# Sampling a boy name beginning with Q..
# all items have <eos>
# name: Quille is already in the dataset
# name: Quintan is already in the dataset
# name: Quinten is already in the dataset
# name: Quintin is already in the dataset
# name: Quinton is already in the dataset
# name: Quilley is a new name!
# name: Quillie is a new name!
# name: Quillio is a new name!
# name: Quintino is a new name!
# name: Quilleigh is a new name!
#
# Sampling a boy name beginning with R..
# all items have <eos>
# name: Rolle is already in the dataset
# name: Ramond is already in the dataset
# name: Ronell is already in the dataset
# name: Rolley is a new name!
# name: Rodrik is already in the dataset
# name: Randell is already in the dataset
# name: Randley is a new name!
# name: Rodrick is already in the dataset
# name: Roderico is a new name!
# name: Roderick is already in the dataset
#
# Sampling a boy name beginning with S..
# all items have <eos>
# name: Sander is already in the dataset
# name: Sandro is already in the dataset
# name: Stefan is already in the dataset
# name: Sandero is already in the dataset
# name: Stephan is already in the dataset
# name: Stefano is already in the dataset
# name: Sandrick is already in the dataset
# name: Stancley is a new name!
# name: Stephano is already in the dataset
# name: Stancliff is already in the dataset
#
# Sampling a boy name beginning with T..
# all items have <eos>
# name: Timor is already in the dataset
# name: Theod is already in the dataset
# name: Terrel is already in the dataset
# name: Trevan is already in the dataset
# name: Terrell is already in the dataset
# name: Timorio is a new name!
# name: Torrell is a new name!
# name: Theodor is already in the dataset
# name: Thorston is a new name!
# name: Timotheus is already in the dataset
#
# Sampling a boy name beginning with U..
# all items have <eos>
# name: Urie is already in the dataset
# name: Ursh is a new name!
# name: Ullis is a new name!
# name: Urian is a new name!
# name: Uriel is already in the dataset
# name: Urrie is a new name!
# name: Urson is already in the dataset
# name: Uriano is a new name!
# name: Uriell is already in the dataset
# name: Ursell is already in the dataset
#
# Sampling a boy name beginning with V..
# all items have <eos>
# name: Vitor is already in the dataset
# name: Valler is already in the dataset
# name: Vicker is a new name!
# name: Valerio is already in the dataset
# name: Vitorio is already in the dataset
# name: Valentio is a new name!
# name: Valerian is already in the dataset
# name: Valentino is already in the dataset
# name: Valeriano is already in the dataset
# name: Vincenzio is already in the dataset
#
# Sampling a boy name beginning with W..
# all items have <eos>
# name: Will is already in the dataset
# name: Wille is already in the dataset
# name: Willy is already in the dataset
# name: Willer is already in the dataset
# name: Willey is already in the dataset
# name: Willie is already in the dataset
# name: Willis is already in the dataset
# name: Willbert is a new name!
# name: Willburg is a new name!
# name: Williston is already in the dataset
#
# Sampling a boy name beginning with X..
# all items have <eos>
# name: Xing is a new name!
# name: Xander is already in the dataset
# name: Xandre is a new name!
# name: Xandro is already in the dataset
# name: Xachar is a new name!
# name: Xandero is a new name!
# name: Xandrio is a new name!
# name: Xandron is a new name!
# name: Xandros is already in the dataset
# name: Xandrick is a new name!
#
# Sampling a boy name beginning with Y..
# all items have <eos>
# name: Yolan is already in the dataset
# name: Yoshi is already in the dataset
# name: Yandra is a new name!
# name: Yandre is a new name!
# name: Yerrik is a new name!
# name: Yoland is already in the dataset
# name: Yandrio is a new name!
# name: Yashund is a new name!
# name: Yerrick is a new name!
# name: Yoshiah is a new name!
#
# Sampling a boy name beginning with Z..
# all items have <eos>
# name: Zander is already in the dataset
# name: Zandro is already in the dataset
# name: Zachar is already in the dataset
# name: Zachery is already in the dataset
# name: Zachiel is a new name!
# name: Zacharia is already in the dataset
# name: Zacheria is already in the dataset
# name: Zachiria is a new name!
# name: Zephirio is a new name!
# name: Zachariah is already in the dataset
#
# Sampling a girl name beginning with A..
# all items have <eos>
# name: Andra is already in the dataset
# name: Andrea is already in the dataset
# name: Andria is already in the dataset
# name: Andrie is already in the dataset
# name: Annessa is a new name!
# name: Angelia is already in the dataset
# name: Allissa is already in the dataset
# name: Allyssa is already in the dataset
# name: Angelice is a new name!
# name: Allissandre is a new name!
#
# Sampling a girl name beginning with B..
# all items have <eos>
# name: Briget is already in the dataset
# name: Brynni is a new name!
# name: Bridget is already in the dataset
# name: Britanni is already in the dataset
# name: Britanny is already in the dataset
# name: Brittani is already in the dataset
# name: Brittany is already in the dataset
# name: Brigette is already in the dataset
# name: Brittanni is already in the dataset
# name: Bridgette is already in the dataset
#
# Sampling a girl name beginning with C..
# all items have <eos>
# name: Catrina is already in the dataset
# name: Christal is already in the dataset
# name: Christle is already in the dataset
# name: Christyn is already in the dataset
# name: Christell is already in the dataset
# name: Christina is already in the dataset
# name: Christabel is already in the dataset
# name: Christelle is already in the dataset
# name: Christalynn is a new name!
# name: Christabelle is already in the dataset
#
# Sampling a girl name beginning with D..
# all items have <eos>
# name: Dora is already in the dataset
# name: Delisa is already in the dataset
# name: Doreen is already in the dataset
# name: Dorita is already in the dataset
# name: Dulcia is already in the dataset
# name: Dulcie is already in the dataset
# name: Destina is already in the dataset
# name: Destine is already in the dataset
# name: Destinia is a new name!
# name: Doralynn is already in the dataset
#
# Sampling a girl name beginning with E..
# all items have <eos>
# name: Elise is already in the dataset
# name: Ellina is already in the dataset
# name: Elmira is already in the dataset
# name: Erline is already in the dataset
# name: Ellenor is already in the dataset
# name: Ellissa is already in the dataset
# name: Elisabet is already in the dataset
# name: Elizabet is already in the dataset
# name: Elisabeth is already in the dataset
# name: Elizabeth is already in the dataset
#
# Sampling a girl name beginning with F..
# all items have <eos>
# name: Freda is already in the dataset
# name: Felicia is already in the dataset
# name: Francee is already in the dataset
# name: Franciska is already in the dataset
# name: Frederica is already in the dataset
# name: Frederice is a new name!
# name: Frederika is already in the dataset
# name: Fredricka is already in the dataset
# name: Franchelle is a new name!
# name: Fredericka is already in the dataset
#
# Sampling a girl name beginning with G..
# all items have <eos>
# name: Gloria is already in the dataset
# name: Gracia is already in the dataset
# name: Georgia is already in the dataset
# name: Glennis is already in the dataset
# name: Griselle is already in the dataset
# name: Georganne is already in the dataset
# name: Glorianne is already in the dataset
# name: Gloriella is a new name!
# name: Georgeanne is already in the dataset
# name: Georgianne is already in the dataset
#
# Sampling a girl name beginning with H..
# all items have <eos>
# name: Halli is already in the dataset
# name: Hilda is already in the dataset
# name: Hilde is already in the dataset
# name: Hallee is already in the dataset
# name: Hallie is a new name!
# name: Hillia is already in the dataset
# name: Hillie is already in the dataset
# name: Halleigh is a new name!
# name: Hildriga is a new name!
# name: Hildrige is a new name!
#
# Sampling a girl name beginning with I..
# all items have <eos>
# name: Illia is already in the dataset
# name: Irena is already in the dataset
# name: Irene is already in the dataset
# name: Irina is already in the dataset
# name: Irenia is a new name!
# name: Isabel is already in the dataset
# name: Isolda is already in the dataset
# name: Illiana is already in the dataset
# name: Isabeth is a new name!
# name: Isabelle is already in the dataset
#
# Sampling a girl name beginning with J..
# all items have <eos>
# name: Julia is already in the dataset
# name: Janell is already in the dataset
# name: Janelle is already in the dataset
# name: Jennell is already in the dataset
# name: Juliana is already in the dataset
# name: Jennisha is already in the dataset
# name: Julietta is already in the dataset
# name: Juliette is already in the dataset
# name: Jacquelyn is already in the dataset
# name: Jacquelynn is already in the dataset
#
# Sampling a girl name beginning with K..
# all items have <eos>
# name: Krystal is already in the dataset
# name: Kristell is already in the dataset
# name: Kristina is already in the dataset
# name: Krystina is already in the dataset
# name: Kristabel is already in the dataset
# name: Krystabel is already in the dataset
# name: Kristalynn is already in the dataset
# name: Kristianna is already in the dataset
# name: Kristianne is already in the dataset
# name: Krystalynn is a new name!
#
# Sampling a girl name beginning with L..
# all items have <eos>
# name: Loree is already in the dataset
# name: Loria is already in the dataset
# name: Lorra is already in the dataset
# name: Lorri is already in the dataset
# name: Laurie is already in the dataset
# name: Lorree is already in the dataset
# name: Lorrie is already in the dataset
# name: Laurelle is already in the dataset
# name: Laurianne is already in the dataset
# name: Laurielle is a new name!
#
# Sampling a girl name beginning with M..
# all items have <eos>
# name: Marcee is already in the dataset
# name: Marcie is already in the dataset
# name: Melissa is already in the dataset
# name: Michell is already in the dataset
# name: Marielle is already in the dataset
# name: Marcelle is already in the dataset
# name: Marcelyn is already in the dataset
# name: Michelle is already in the dataset
# name: Mariselle is a new name!
# name: Marcelynn is a new name!
#
# Sampling a girl name beginning with N..
# all items have <eos>
# name: Nora is already in the dataset
# name: Nicola is already in the dataset
# name: Nikola is already in the dataset
# name: Nicolia is a new name!
# name: Nicolle is already in the dataset
# name: Nickola is already in the dataset
# name: Nicoleta is a new name!
# name: Nicoline is already in the dataset
# name: Nicoletta is already in the dataset
# name: Nicolette is already in the dataset
#
# Sampling a girl name beginning with O..
# all items have <eos>
# name: Oria is already in the dataset
# name: Ondra is already in the dataset
# name: Orelia is already in the dataset
# name: Orella is already in the dataset
# name: Orelle is a new name!
# name: Oriana is already in the dataset
# name: Ornelle is a new name!
# name: Orianna is already in the dataset
# name: Orianne is already in the dataset
# name: Ottilia is already in the dataset
#
# Sampling a girl name beginning with P..
# all items have <eos>
# name: Porsha is already in the dataset
# name: Patrina is already in the dataset
# name: Patrice is already in the dataset
# name: Petrina is already in the dataset
# name: Phillia is a new name!
# name: Phillie is already in the dataset
# name: Phillis is already in the dataset
# name: Patricia is a new name!
# name: Petronia is already in the dataset
# name: Philliss is a new name!
#
# Sampling a girl name beginning with Q..
# all items have <eos>
# name: Quina is already in the dataset
# name: Quinna is already in the dataset
# name: Quilla is already in the dataset
# name: Quinnee is a new name!
# name: Quillee is a new name!
# name: Quillia is a new name!
# name: Quillie is a new name!
# name: Quentine is a new name!
# name: Quintina is already in the dataset
# name: Quillianne is a new name!
#
# Sampling a girl name beginning with R..
# all items have <eos>
# name: Rosanne is already in the dataset
# name: Rosalyn is already in the dataset
# name: Roselle is already in the dataset
# name: Roselyn is already in the dataset
# name: Rosalynn is already in the dataset
# name: Roselind is already in the dataset
# name: Roselynn is already in the dataset
# name: Rosalynne is already in the dataset
# name: Roselinda is already in the dataset
# name: Roselynne is a new name!
#
# Sampling a girl name beginning with S..
# all items have <eos>
# name: Sheree is already in the dataset
# name: Sherri is already in the dataset
# name: Sherry is already in the dataset
# name: Shandra is already in the dataset
# name: Sherice is already in the dataset
# name: Sherree is already in the dataset
# name: Sherrie is already in the dataset
# name: Sherryl is already in the dataset
# name: Shantell is already in the dataset
# name: Sherylynn is a new name!
#
# Sampling a girl name beginning with T..
# all items have <eos>
# name: Tamara is already in the dataset
# name: Terree is already in the dataset
# name: Terrie is already in the dataset
# name: Trisha is already in the dataset
# name: Tiffani is already in the dataset
# name: Tiffany is already in the dataset
# name: Tiffanie is already in the dataset
# name: Tiffenie is already in the dataset
# name: Tiffinia is a new name!
# name: Tiffinie is already in the dataset
#
# Sampling a girl name beginning with U..
# all items have <eos>
# name: Uria is already in the dataset
# name: Ullie is a new name!
# name: Ursia is a new name!
# name: Urella is a new name!
# name: Urelle is a new name!
# name: Uriana is a new name!
# name: Urianne is a new name!
# name: Uriella is already in the dataset
# name: Urielle is a new name!
# name: Ursella is already in the dataset
#
# Sampling a girl name beginning with V..
# all items have <eos>
# name: Verna is already in the dataset
# name: Verona is already in the dataset
# name: Vickee is already in the dataset
# name: Vickie is already in the dataset
# name: Vernice is already in the dataset
# name: Valentia is already in the dataset
# name: Vernette is already in the dataset
# name: Veronica is already in the dataset
# name: Veronice is already in the dataset
# name: Veronika is already in the dataset
#
# Sampling a girl name beginning with W..
# all items have <eos>
# name: Willa is already in the dataset
# name: Willi is already in the dataset
# name: Winora is a new name!
# name: Willee is already in the dataset
# name: Willie is already in the dataset
# name: Willine is a new name!
# name: Willetta is already in the dataset
# name: Willette is already in the dataset
# name: Williana is a new name!
# name: Willianne is a new name!
#
# Sampling a girl name beginning with X..
# all items have <eos>
# name: Xora is a new name!
# name: Xanna is a new name!
# name: Xandra is already in the dataset
# name: Xandre is a new name!
# name: Xillia is a new name!
# name: Xandrea is a new name!
# name: Xandria is already in the dataset
# name: Xandrina is a new name!
# name: Xilliana is a new name!
# name: Xillianne is a new name!
#
# Sampling a girl name beginning with Y..
# all items have <eos>
# name: Yanna is already in the dataset
# name: Yulia is already in the dataset
# name: Yannee is a new name!
# name: Yannie is a new name!
# name: Yasmin is already in the dataset
# name: Yoline is a new name!
# name: Yasmine is already in the dataset
# name: Yolanda is already in the dataset
# name: Yolande is already in the dataset
# name: Yolanthe is already in the dataset
#
# Sampling a girl name beginning with Z..
# all items have <eos>
# name: Zora is already in the dataset
# name: Zenia is already in the dataset
# name: Zoria is already in the dataset
# name: Zorie is a new name!
# name: Zandra is already in the dataset
# name: Zondra is already in the dataset
# name: Zorina is already in the dataset
# name: Zorine is already in the dataset
# name: Zandria is a new name!
# name: Zandrina is a new name!

# %%
generate_names(model, prime="A", category="boy", beam_width=3, dataset=total_df)

# %%
generate_names(model, prime="Z", category="boy", beam_width=3, dataset=total_df)

# %%
generate_names(model, prime="Z", category="girl", beam_width=3, dataset=total_df)

# %%
total_df.babyname.str.contains("Andrick").sum()

# %%
total_df[lambda x: x.babyname == "Andrian"]

# %%
a = defaultdict()

# %%
print(a.get('a'))

# %%
beam_basket = OrderedDict()
beam_basket['A'] = 1.0
beam_basket['B'] = 0.8
beam_basket['C'] = 0.7
beam_basket['D'] = 1.2

# %%
sorted(beam_basket.items(), key=lambda x: x[1], reverse=True)

# %%
data_loader.BABYNAME.vocab.stoi
